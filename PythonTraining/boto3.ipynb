# %%
pip install boto3
# Out:
# ...
#
# ...

# %%
import boto3

# %%
ec=boto3.client("ec2")
ec.run_instance(
    ImageId="ami-03643cf1426c9b40b",
    Instance="t2.micro",
    MinCount=1,
    MaxCount=1
)
# Out:
# ---------------------------------------------------------------------------
# NoRegionError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ec=boto3.client("ec2")
#
# File ~\anaconda3\Lib\site-packages\boto3\__init__.py:92, in client(*args, **kwargs)
#      86 def client(*args, **kwargs):
#      87     """
#      88     Create a low-level service client by name using the default session.
#      89
#      90     See :py:meth:`boto3.session.Session.client`.
#      91     """
# ---> 92     return _get_default_session().client(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\boto3\session.py:299, in Session.client(self, service_name, region_name, api_version, use_ssl, verify, endpoint_url, aws_access_key_id, aws_secret_access_key, aws_session_token, config)
#     217 def client(
#     218     self,
#     219     service_name,
#    (...)
#     228     config=None,
#     229 ):
#     230     """
# ...
