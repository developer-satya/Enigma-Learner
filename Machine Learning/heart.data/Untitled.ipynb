# %%
import pandas as pd

# %%
heart_data = pd.read_csv("./heart.data.csv")

# %%
heart_data
# Out:
#      Unnamed: 0     biking    smoking  heart.disease
# 0             1  30.801246  10.896608      11.769423
# 1             2  65.129215   2.219563       2.854081
# 2             3   1.959665  17.588331      17.177803
# 3             4  44.800196   2.802559       6.816647
# 4             5  69.428454  15.974505       4.062224
# ..          ...        ...        ...            ...
# 493         494  47.660440  27.562464      11.294392
# 494         495  45.097203  21.385620       9.616762
# 495         496   8.279743   6.423720      13.495168
# 496         497  42.345863  20.741328      10.115865
# 497         498  30.774254  23.610175      11.843556
#
# [498 rows x 4 columns]

# %%
# heart_data['heart_disease'] = heart_data["heart.disease"].map({if val > 10.2:1,else val>18})
count=0
for val in heart_data['heart.disease']:
    if int(val) > 10:
        heart_data['heart_disease'].iloc[count] = 0
    else:
        heart_data['heart_disease'].iloc[count] = 1
    count=count+1
# Out:
# C:\Users\sanaya\AppData\Local\Temp\ipykernel_13752\1742074490.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart_data['heart_disease'].iloc[count] = 0
# C:\Users\sanaya\AppData\Local\Temp\ipykernel_13752\1742074490.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heart_data['heart_disease'].iloc[count] = 1

# %%
heart_data
# Out:
#      Unnamed: 0     biking    smoking  heart.disease  heart_disease
# 0             1  30.801246  10.896608      11.769423              0
# 1             2  65.129215   2.219563       2.854081              1
# 2             3   1.959665  17.588331      17.177803              0
# 3             4  44.800196   2.802559       6.816647              1
# 4             5  69.428454  15.974505       4.062224              1
# ..          ...        ...        ...            ...            ...
# 493         494  47.660440  27.562464      11.294392              0
# 494         495  45.097203  21.385620       9.616762              1
# 495         496   8.279743   6.423720      13.495168              0
# 496         497  42.345863  20.741328      10.115865              1
# 497         498  30.774254  23.610175      11.843556              0
#
# [498 rows x 5 columns]

# %%
type(heart_disease)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

# %%
y1 = heart_data['biking']

y2 = heart_data['smoking']
 
x = heart_data['heart.disease']

plt.figure(figsize=(10, 6))
plt.scatter(y2, y1, c=x, cmap='bwr', marker='o', edgecolors='k', s=100)
plt.colorbar(label='Heart Disease (0: No, 1: Yes)')
plt.title('Chances of Heart Disease based on Smoking and Riding Habits')
plt.xlabel('Smoking (%)')
plt.ylabel('Riding (%)')
plt.grid(True)
plt.show()

# %%
import numpy as np

# %%
new_x = [[y1,y2]]
X = np.array(new_x).reshape(498,2)
y = np.array(x).ndim
# df = pd.DataFrame(x)
# newdf = df.transpose()
# X = np.array(newdf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 3
#       1 new_x = [[y1,y2]]
#       2 X = np.array(new_x).reshape(498,2)
# ----> 3 y = np.array(x).reshape(0,2)
#
# ValueError: cannot reshape array of size 498 into shape (0,2)

# %%
X.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %%
len(X)
# Out:
# 498

# %%
len(y)
# Out:
# 498

# %%
print(X)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


# split the train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=23)

# LogisticRegression
# model = LogisticRegression(random_state=0)
new_model = LinearRegression()
new_model.fit(X_train, y_train)
# model.fit(X_train, y_train)
 
# Prediction
y_pred = new_model.predict(X_test)

print(mean_absolute_error(y_pred, y_test))
print(mean_squared_error(y_pred, y_test))
print(new_model.score(X_test,y_test))
 
# acc = accuracy_score(y_test, y_pred)
# print("Logistic Regression model accuracy (in %):", acc*100)
# Out:
# 0.5017154392733023
# 0.2565003120924937
# -0.02764548113979881

# %%
len(y)
# Out:
# 498

# %%
X.ndim

# %%
y.ndim
